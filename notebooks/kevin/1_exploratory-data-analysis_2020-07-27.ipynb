# %%
import pandas as pd
import scipy as sp
import numpy as np

# %%
df = pd.read_csv('~/sm/phil/SharpestMinds-/nfl-2019.csv')

# %%
df.head()
# Out:
#        GameId    GameDate  Quarter  Minute  Second OffenseTeam DefenseTeam  \
# 0  2019100605   10/6/2019        1       2      25         OAK         CHI
# 1  2019100605   10/6/2019        1       1      45         OAK         CHI
# 2  2019101400  10/14/2019        1      10      34         DET          GB
# 3  2019101400  10/14/2019        1       9      55         DET          GB
# 4  2019101400  10/14/2019        1       9      10         DET          GB
#
#    Down  ToGo  YardLine  ...  IsTwoPointConversion  \
# 0     1    10        50  ...                     0
# 1     2     9        51  ...                     0
# 2     1    10        84  ...                     0
# 3     2     9        85  ...                     0
# 4     3     3        91  ...                     0
#
#    IsTwoPointConversionSuccessful  RushDirection  YardLineFixed  \
# 0                               0            NaN             50
# 1                               0    RIGHT GUARD             49
# ...

# %%
df.GameId.unique().sum()
# Out:
# 478528162727
